# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pickle.load( open( "./../data_set.p", "rb" ) )
len(df.index)
# Out:
# 3605250

# %%
pd.set_option("display.max_rows", 300)
t = df['action_cleaned'].value_counts().reset_index()
t.columns = ['unique_values', 'counts']
t
# Out:
#                               unique_values  counts
# 0                        scroll_on_homepage  397840
# 1                   click_on_number_details  275063
# 2                             load_homepage  220057
# 3                                    search  212071
# 4               interact_with_pop_up_window  188921
# 5                     click_on_subscription  186868
# 6                             click_on_name  158773
# 7                            click_on_other  117874
# 8                click_next_in_subscr_order   84420
# 9                    empty_subselect_ignore   81549
# 10                             submit_order   77756
# 11                            click_log_out   76421
# 12                     open_invoice_account   71273
# 13                         click_on_confirm   70786
# 14                            click_on_save   65577
# 15                      go_back_to_homepage   62803
# 16                           click_on_arrow   55257
# 17                          load_other_page   49020
# 18                       click_on_terminate   46608
# 19                    loading subscriptions   44872
# 20             click_on_subscription_detail   44132
# 21                      click_on_edit_field   39435
# 22                      click_on_agreements   38064
# 23                click_on_new_subscription   33863
# 24               adding_additional_services   29841
# 25                        account_reference   28709
# 26                         click_on_company   27900
# 27                  click_on_administrators   26623
# 28                 click_on_unpaid_invoices   24558
# 29                        click_on_sim_card   24084
# 30                           interrupt_task   23903
# 31                             activate_new   23785
# 32              click_on_menu_subscriptions   23664
# 33                               start_chat   23661
# 34                      click_on_time_range   22108
# 35                 click_on_accept_continue   22105
# 36                         click_on_MBN_sub   22000
# 37                  click_on_change_account   21766
# 38                     click_on_bedrift_sub   21522
# 39                           see_agreements   21285
# 40                            click_on_send   21242
# 41                        click_on_activate   21197
# 42                    click_on_new_settings   16880
# 43                     click_on_find_person   14491
# 44                            click_on_list   13227
# 45                          click_on_billed   13121
# 46                   click_on_menu_accounts   12619
# 47                          click_on_select   12350
# 48                           click_on_trash   12147
# 49                      click_on_get_report   12102
# 50                  click_on_order_overview   12017
# 51                            click_on_path   11939
# 52                      click_on_contact_us   11899
# 53                            click_on_lock   11721
# 54                            click_on_data   11244
# 55                      click_on_new_report   11088
# 56     click_new_subscription_from_template   10312
# 57                     click_on_see_history   10200
# 58                         click_on_account    9167
# 59                          click_on_cancel    8923
# 60                   scroll_on_reports_page    8345
# 61                        click_on_external    7928
# 62              click_on_change_user_on_sub    7842
# 63                  click_on_sub_voice_data    7057
# 64                    send_sms_to_employees    6803
# 65                       click_on_user_type    6758
# 66                             click_on_add    6712
# 67                             activate_sim    6638
# 68                              see_invoice    6373
# 69                        select_no_binding    5915
# 70      click_new_subscription_from_scratch    5595
# 71                          export_to_excel    5537
# 72                       click_on_activated    5274
# 73                           click_on_cloud    5214
# 74                  click_on_surf_datapakke    4783
# 75                         click_on_navicon    4094
# 76          order_overview_check_change_sub    4092
# 77                          click_on_abroad    3953
# 78               click_on_subscription_type    3755
# 79                         click_on_pointer    3751
# 80                        click_on_find_PUK    3735
# 81        click_on_change_account_reference    3703
# 82                       scroll_on_simcards    3615
# 83                        add_new_agreement    3532
# 84                        click_on_question    3499
# 85                  scroll_on_accounts_page    3370
# 86    order_overview_check_completed_orders    3278
# 87             click_on_new_invoice_account    3244
# 88                        click_on_mbnaktiv    3099
# 89                click_on_agreement_detail    2888
# 90                             click_on_sms    2740
# 91              explore_additional_services    2673
# 92                    click_on_other_change    2615
# 93                        click_on_datacard    2608
# 94                         click_on_overall    2577
# 95                   select_on_no_reference    2511
# 96                   click_on_see_dismissed    2510
# 97                       click_on_configure    2407
# 98                        click_on_homepage    2392
# 99                         click_on_telenor    2374
# 100                         click_on_speach    2361
# 101                   click_on_installed_in    2344
# 102                         click_on_expand    2306
# 103                          click_on_inbox    2303
# 104                      click_on_reference    2265
# 105                          click_on_fixed    2200
# 106                        click_on_refresh    1970
# 107                click_on_recommendations    1958
# 108                        warnings_product    1813
# 109                            click_on_m2m    1799
# 110                 click_on_menu_locations    1797
# 111                click_on_send_entry_code    1772
# 112                         change_language    1703
# 113                     click_on_self_owner    1652
# 114                scroll_on_page_downloads    1619
# 115                           click_on_paid    1560
# 116                         click_on_update    1556
# 117                           click_on_menu    1507
# 118  order_overview_check_orders_in_process    1506
# 119                      click_on_check_out    1428
# 120               click_on_sim_card_details    1401
# 121                           click_on_APIs    1374
# 122     click_on_locations_of subscriptions    1341
# 123                  click_on_error_details    1320
# 124                      GDPR_related_click    1285
# 125                         click_on_change    1230
# 126                   click_on_active_users    1226
# 127                   click_on_use_existing    1209
# 128                   click_on_no_data_incl    1209
# 129                           click_on_copy    1186
# 130                  click_on_cloud_product    1098
# 131           click_on_terms_and_conditions    1089
# 132                    click_on_give_access    1078
# 133                     click_on_add_dealer    1048
# 134                      click_on_last_used    1035
# 135                    click_on_mbn_details    1023
# 136                  click_on_add_post_code     997
# 137           click_on_manage_subscriptions     895
# 138             click_on_sim_number_details     890
# 139                     click_on_magic_link     881
# 140            click_on_billing_information     834
# 141                    click_on_dealer_list     825
# 142                     click_on_change_sub     817
# 143         click_whether_you_can_get_fiber     799
# 144                  click_on_notifications     738
# 145                        click_on_dealers     689
# 146                       click_on_stocking     680
# 147             click_on_change_invoice_ref     675
# 148                    click_on_verify_code     665
# 149                    click_on_mobilnummer     619
# 150        click_on_order_new_cloud_service     606
# 151           click_on_give_the_same_access     597
# 152                          click_on_price     593
# 153                       click_on_show_all     591
# 154                          click_on_mobil     591
# 155                  click_on_pages_details     588
# 156                    click_on_information     580
# 157                      click_on_campaigns     571
# 158     click_on_send_order_status_to_email     562
# 159               click_on_campaign_details     543
# 160                   click_on_not_relevant     486
# 161                           click_on_user     481
# 162          click_on_active_cloud_services     470
# 163                        click_on_address     466
# 164                       click_on_twin_sim     432
# 165                      click_on_no_access     410
# 166                  click_on_enhet_details     398
# 167                    scroll_on_page_costs     379
# 168                        click_on_unknown     377
# 169        click_on_failed_to_retrieve_data     377
# 170                         click_on_fusion     370
# 171                      click_on_ownership     320
# 172     order_overview_check_change_account     308
# 173                  click_on_paper_invoice     304
# 174                         click_on_locked     290
# 175    click_on_discount_consumption_inland     284
# 176     order_overview_check_cancelled_subs     279
# 177         click_on_companies_with_product     264
# 178                     click_on_guidelines     240
# 179                click_on_role_department     233
# 180                          select_binding     231
# 181                   click_on_user_details     220
# 182                          click_on_crown     220
# 183                      order_invoice_copy     213
# 184                           click_on_star     203
# 185                click_on_safety_products     198
# 186                          click_on_pause     186
# 187         click_on_choose_in_subscr_order     186
# 188                 click_on_menu_sim_cards     180
# 189               scroll_on_fakturakontroll     173
# 190                           click_on_plus     167
# 191               click_on_equipment_change     164
# 192                          return_product     159
# 193           order_overview_check_port_ins     153
# 194            select_on_discounted_product     141
# 195                         click_on_remove     137
# 196                 click_on_personal_users     130
# 197                       click_add_account     123
# 198                 scroll_on_messages_page     122
# 199               click_on_invoice_by_email     108
# 200               click_on_advanced_reports     106
# 201                            click_on_map     103
# 202                  click_on_remove_access      97
# 203                click_on_user_references      96
# 204                         click_on_filter      88
# 205                      click_on_ordercase      82
# 206               click_on_give_read_access      70
# 207       click_on_did_you_notice_new_login      62
# 208                          go_back_to_top      33
# 209        order_overview_check_locked_subs      24
# 210                     click_on_mobile_sub       9
# 211                       click_on_feedback       7
# 212      order_overview_check_single_orders       1
# 213       order_overview_check_other_orders       1

# %%
plt.figure(figsize=(8,40))
ax = sns.barplot(x="counts", y="unique_values", data=t, orient='h')
#ax.set_xscale('log')
