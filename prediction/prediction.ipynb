# %%
# predicting next action given current action

import pickle
import matplotlib.pyplot as plt

plt.figure()

with open('logs/action.p', 'rb') as f:
    logs = pickle.load(f)

# %%
plt.plot(logs['train_loss_list'])

# %%
plt.plot(logs['train_accuracies_list'])

# %%
plt.plot(logs['validation_accuracies_list'])

# %%
print('test accuracy:',logs['test_accuracy'])
# Out:
# test accuracy: 0.0
